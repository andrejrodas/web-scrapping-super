# %%
import json
import pandas as pd
from pathlib import Path
from datetime import datetime

# Set up paths
data_dir = Path("../data")
print(f"Data directory: {data_dir.absolute()}")
# Out:
# Data directory: c:\Users\Usuario\Documents\GitHub\web-scrapping super\notebooks\..\data

# %%
# Find the latest JSON file in the data folder
json_files = list(data_dir.glob("products_*.json"))
if not json_files:
    raise FileNotFoundError("No JSON files found in data folder")

# Sort by modification time and get the latest
latest_json = max(json_files, key=lambda p: p.stat().st_mtime)
print(f"Latest JSON file: {latest_json.name}")
print(f"Modified: {datetime.fromtimestamp(latest_json.stat().st_mtime)}")
# Out:
# Latest JSON file: products_20251118_010114.json
# Modified: 2025-11-18 01:01:14.561624

# %%
# Load the JSON file
with open(latest_json, "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract metadata and products
metadata = data.get("metadata", {})
products = data.get("products", [])

print(f"Total products: {len(products)}")
print(f"Scraped at: {metadata.get('scraped_at', 'N/A')}")
print(f"Source: {metadata.get('source', 'N/A')}")
print(f"\nFirst product keys: {list(products[0].keys()) if products else 'No products'}")
# Out:
# Total products: 1922
# Scraped at: 2025-11-18T01:01:14.485520
# Source: misuperfresh.com.gt
#
# First product keys: ['name', 'price', 'description', 'barcode', 'stock', 'offer_price', 'offer_description', 'image_url', 'subcategory', 'category', 'raw_data']

# %%
# Create DataFrame from products
# Exclude 'raw_data' field to match CSV structure
df = pd.DataFrame(products)

# Remove raw_data column if it exists
if "raw_data" in df.columns:
    df = df.drop(columns=["raw_data"])

print(f"DataFrame shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nDataFrame info:")
df.info()
# Out:
# DataFrame shape: (1922, 10)
#
# Columns: ['name', 'price', 'description', 'barcode', 'stock', 'offer_price', 'offer_description', 'image_url', 'subcategory', 'category']
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1922 entries, 0 to 1921
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1922 non-null   object
#  1   price              1922 non-null   object
#  2   description        1922 non-null   object
#  3   barcode            1922 non-null   int64
#  4   stock              1922 non-null   float64
#  5   offer_price        1922 non-null   object
#  6   offer_description  1922 non-null   object
#  7   image_url          1922 non-null   object
#  8   subcategory        1922 non-null   object
#  9   category           1922 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 150.3+ KB

# %%
# Display first few rows
print("First 5 rows:")
df.head()
# Out:
# First 5 rows:
#                                                 name   price  \
# 0  Aceite Better Body Foods Almendra Liquida Fras...  102.95
# 1                  Aceite Capullo Envase Poly 1500ml   35.85
# 2              Aceite Capullo Natural Doy Pack 750ml   21.95
# 3          Aceite Capullo 100% Vegetal Botella 750ml   21.75
# 4   Aceite De Oliva Filippo Berio Extra Virgen 500ml  104.95
#
#                                          description  barcode  stock  \
# 0  Aceite Better Body Foods Almendra Liquida Fras...   101581   15.0
# 1                  Aceite Capullo Envase Poly 1500ml   118141    7.0
# 2              Aceite Capullo Natural Doy Pack 750ml   118143    8.0
# 3          Aceite Capullo 100% Vegetal Botella 750ml   118128   30.0
# 4   Aceite De Oliva Filippo Berio Extra Virgen 500ml   266149    5.0
#
#   offer_price offer_description  \
# 0       93.45            Oferta
# 1       32.25            Oferta
# 2       16.75            Oferta
# 3       16.95            Oferta
# 4       85.65            Oferta
#
#                                            image_url        subcategory  \
# 0  https://res.cloudinary.com/gtagt/image/upload/...  Aceite Comestible
# 1  https://res.cloudinary.com/gtagt/image/upload/...  Aceite Comestible
# 2  https://res.cloudinary.com/gtagt/image/upload/...  Aceite Comestible
# 3  https://res.cloudinary.com/gtagt/image/upload/...  Aceite Comestible
# 4  https://res.cloudinary.com/gtagt/image/upload/...  Aceite Comestible
#
#     category
# 0  Abarrotes
# 1  Abarrotes
# 2  Abarrotes
# 3  Abarrotes
# 4  Abarrotes

# %%
# Check the column order matches the CSV structure
# Expected CSV columns: barcode, category, description, image_url, name, offer_description, offer_price, price, stock, subcategory
expected_columns = ["barcode", "category", "description", "image_url", "name", 
                   "offer_description", "offer_price", "price", "stock", "subcategory"]

# Reorder columns to match CSV structure (if they exist)
available_columns = [col for col in expected_columns if col in df.columns]
other_columns = [col for col in df.columns if col not in expected_columns]

# Reorder: expected columns first, then others
df_ordered = df[available_columns + other_columns]

print(f"Reordered DataFrame columns: {list(df_ordered.columns)}")
df_ordered.head()
# Out:
# Reordered DataFrame columns: ['barcode', 'category', 'description', 'image_url', 'name', 'offer_description', 'offer_price', 'price', 'stock', 'subcategory']
#    barcode   category                                        description  \
# 0   101581  Abarrotes  Aceite Better Body Foods Almendra Liquida Fras...
# 1   118141  Abarrotes                  Aceite Capullo Envase Poly 1500ml
# 2   118143  Abarrotes              Aceite Capullo Natural Doy Pack 750ml
# 3   118128  Abarrotes          Aceite Capullo 100% Vegetal Botella 750ml
# 4   266149  Abarrotes   Aceite De Oliva Filippo Berio Extra Virgen 500ml
#
#                                            image_url  \
# 0  https://res.cloudinary.com/gtagt/image/upload/...
# 1  https://res.cloudinary.com/gtagt/image/upload/...
# 2  https://res.cloudinary.com/gtagt/image/upload/...
# 3  https://res.cloudinary.com/gtagt/image/upload/...
# 4  https://res.cloudinary.com/gtagt/image/upload/...
#
#                                                 name offer_description  \
# 0  Aceite Better Body Foods Almendra Liquida Fras...            Oferta
# 1                  Aceite Capullo Envase Poly 1500ml            Oferta
# 2              Aceite Capullo Natural Doy Pack 750ml            Oferta
# 3          Aceite Capullo 100% Vegetal Botella 750ml            Oferta
# 4   Aceite De Oliva Filippo Berio Extra Virgen 500ml            Oferta
#
#   offer_price   price  stock        subcategory
# 0       93.45  102.95   15.0  Aceite Comestible
# 1       32.25   35.85    7.0  Aceite Comestible
# 2       16.75   21.95    8.0  Aceite Comestible
# 3       16.95   21.75   30.0  Aceite Comestible
# 4       85.65  104.95    5.0  Aceite Comestible

# %%
# Rename columns to Spanish before saving
column_mapping = {
    "barcode": "codigo_barras",
    "category": "categoria",
    "description": "descripcion",
    "image_url": "url_imagen",
    "name": "nombre",
    "offer_description": "descripcion_oferta",
    "offer_price": "precio_oferta",
    "price": "precio",
    "stock": "inventario",
    "subcategory": "subcategoria"
}

# Rename columns (only rename columns that exist)
df_spanish = df_ordered.rename(columns={k: v for k, v in column_mapping.items() if k in df_ordered.columns})

print("Column names changed to Spanish:")
print(f"Before: {list(df_ordered.columns)}")
print(f"After:  {list(df_spanish.columns)}")
df_spanish.head()
# Out:
# Column names changed to Spanish:
# Before: ['barcode', 'category', 'description', 'image_url', 'name', 'offer_description', 'offer_price', 'price', 'stock', 'subcategory']
# After:  ['codigo_barras', 'categoria', 'descripcion', 'url_imagen', 'nombre', 'descripcion_oferta', 'precio_oferta', 'precio', 'inventario', 'subcategoria']
#    codigo_barras  categoria  \
# 0         101581  Abarrotes
# 1         118141  Abarrotes
# 2         118143  Abarrotes
# 3         118128  Abarrotes
# 4         266149  Abarrotes
#
#                                          descripcion  \
# 0  Aceite Better Body Foods Almendra Liquida Fras...
# 1                  Aceite Capullo Envase Poly 1500ml
# 2              Aceite Capullo Natural Doy Pack 750ml
# 3          Aceite Capullo 100% Vegetal Botella 750ml
# 4   Aceite De Oliva Filippo Berio Extra Virgen 500ml
#
#                                           url_imagen  \
# 0  https://res.cloudinary.com/gtagt/image/upload/...
# 1  https://res.cloudinary.com/gtagt/image/upload/...
# 2  https://res.cloudinary.com/gtagt/image/upload/...
# 3  https://res.cloudinary.com/gtagt/image/upload/...
# 4  https://res.cloudinary.com/gtagt/image/upload/...
#
#                                               nombre descripcion_oferta  \
# 0  Aceite Better Body Foods Almendra Liquida Fras...             Oferta
# 1                  Aceite Capullo Envase Poly 1500ml             Oferta
# 2              Aceite Capullo Natural Doy Pack 750ml             Oferta
# 3          Aceite Capullo 100% Vegetal Botella 750ml             Oferta
# 4   Aceite De Oliva Filippo Berio Extra Virgen 500ml             Oferta
#
#   precio_oferta  precio  inventario       subcategoria
# 0         93.45  102.95        15.0  Aceite Comestible
# 1         32.25   35.85         7.0  Aceite Comestible
# 2         16.75   21.95         8.0  Aceite Comestible
# 3         16.95   21.75        30.0  Aceite Comestible
# 4         85.65  104.95         5.0  Aceite Comestible

# %%
# Save to CSV with Spanish column names
output_filename = latest_json.stem.replace(".json", "") + "_from_notebook.csv"
output_path = data_dir / output_filename

# Save to CSV (matching the original CSV format but with Spanish columns)
df_spanish.to_csv(output_path, index=False, encoding="utf-8")
print(f"CSV saved to: {output_path.absolute()}")
print(f"Total rows: {len(df_spanish)}")
# Out:
# CSV saved to: c:\Users\Usuario\Documents\GitHub\web-scrapping super\notebooks\..\data\products_20251118_010114_from_notebook.csv
# Total rows: 1922

# %%
# Display summary statistics (using Spanish column names)
print("Estadísticas Resumen:")
print("=" * 60)
print(f"Total productos: {len(df_spanish)}")
print(f"Categorías únicas: {df_spanish['categoria'].nunique() if 'categoria' in df_spanish.columns else 'N/A'}")
print(f"Subcategorías únicas: {df_spanish['subcategoria'].nunique() if 'subcategoria' in df_spanish.columns else 'N/A'}")
print(f"\nEstadísticas de precios:")
if 'precio' in df_spanish.columns:
    # Convert price to numeric if it's a string
    prices = pd.to_numeric(df_spanish['precio'], errors='coerce')
    print(f"  Precio mínimo: {prices.min():.2f}")
    print(f"  Precio máximo: {prices.max():.2f}")
    print(f"  Precio promedio: {prices.mean():.2f}")
    print(f"  Precio mediano: {prices.median():.2f}")

if 'precio_oferta' in df_spanish.columns:
    offer_prices = pd.to_numeric(df_spanish['precio_oferta'], errors='coerce')
    products_with_offers = offer_prices.notna().sum()
    print(f"\nProductos con ofertas: {products_with_offers} ({products_with_offers/len(df_spanish)*100:.1f}%)")
# Out:
# Estadísticas Resumen:
# ============================================================
# Total productos: 1922
# Categorías únicas: 13
# Subcategorías únicas: 109
#
# Estadísticas de precios:
#   Precio mínimo: 0.75
#   Precio máximo: 494.95
#   Precio promedio: 40.82
#   Precio mediano: 24.95
#
# Productos con ofertas: 1922 (100.0%)

# %%
# Imprimir todas las categorías y subcategorías
print("=" * 60)
print("CATEGORÍAS Y SUBCATEGORÍAS")
print("=" * 60)

# Agrupar por categoría y obtener subcategorías únicas
if 'categoria' in df_spanish.columns and 'subcategoria' in df_spanish.columns:
    # Agrupar por categoría
    categorias_subcategorias = df_spanish.groupby('categoria')['subcategoria'].unique()
    
    # Ordenar alfabéticamente por categoría
    for categoria in sorted(categorias_subcategorias.index):
        subcategorias = categorias_subcategorias[categoria]
        print(f"\nCATEGORIA: {categoria} ({len(subcategorias)} subcategorías)")
        print("-" * 60)
        
        # Ordenar subcategorías alfabéticamente
        for subcat in sorted(subcategorias):
            # Contar productos en esta subcategoría
            count = len(df_spanish[(df_spanish['categoria'] == categoria) & 
                                   (df_spanish['subcategoria'] == subcat)])
            print(f"  SUBCATEGORIA: {subcat} ({count} productos)")
    
    print("\n" + "=" * 60)
    print(f"Total categorías: {df_spanish['categoria'].nunique()}")
    print(f"Total subcategorías: {df_spanish['subcategoria'].nunique()}")
    print(f"Total productos: {len(df_spanish)}")
else:
    print("Error: No se encontraron las columnas 'categoria' o 'subcategoria'")
# Out:
# ============================================================
# CATEGORÍAS Y SUBCATEGORÍAS
# ============================================================
#
# 📁 Abarrotes (29 subcategorías)
# ------------------------------------------------------------
#   └─ Aceite Comestible (18 productos)
#   └─ Aderezos Y Mayonesas (21 productos)
#   └─ Atun Y Sardinas Envasadas (20 productos)
#   └─ Barras De Cereales (2 productos)
#   └─ Café, Te Y Cremoras (55 productos)
#   └─ Cereales (41 productos)
#   └─ Cereales Calientes / Atoles (14 productos)
#   └─ Complementos De Reposteria (13 productos)
#   └─ Especias Y Sazonadores (44 productos)
#   └─ Frijol Envasado (12 productos)
#   └─ Fruta Seca Y Deshidratada (1 productos)
#   └─ Frutas Envasadas Y En Almibar (3 productos)
#   └─ Gelatinas, Flanes Y Pudines (14 productos)
#   └─ Granos Basicos (5 productos)
#   └─ Harinas De Trigo (12 productos)
#   └─ Leche En Polvo (8 productos)
#   └─ Leche Liquida Uht (43 productos)
#   └─ Margarinas Y Mantecas (8 productos)
#   └─ Miel, Jaleas Y Mermeladas (15 productos)
#   └─ Modificadores De Leche (1 productos)
#   └─ Pastas Alimenticias (22 productos)
#   └─ Preparados De Cocina (3 productos)
#   └─ Sal (2 productos)
#   └─ Salsas (23 productos)
#   └─ Sopas Deshidratadas (10 productos)
#   └─ Sopas Tipo Ramen (13 productos)
#   └─ Tomate Procesado (12 productos)
#   └─ Vegetales Envasados (15 productos)
#   └─ Vinagres (3 productos)
#
# 📁 Bebe (4 subcategorías)
# ------------------------------------------------------------
#   └─ Compotas Y Colados (2 productos)
#   └─ Cuidado Personal Del Bebe (13 productos)
#   └─ Pañales Desechables Para Bebe (29 productos)
#   └─ Toallas Humedas De Bebe (4 productos)
#
# 📁 Bebidas (9 subcategorías)
# ------------------------------------------------------------
#   └─ Bebidas De Aloe (3 productos)
#   └─ Bebidas Energizantes E Isotonicas (22 productos)
#   └─ Cervezas (24 productos)
#   └─ Gaseosas (61 productos)
#   └─ Jugos Refrigerados (13 productos)
#   └─ Jugos Y Nectares (25 productos)
#   └─ Refrescos En Polvo Y Concentrados (17 productos)
#   └─ Te Frio Y Refrescos Saludables (17 productos)
#   └─ Vinos (91 productos)
#
# 📁 Carnes Y Embutidos (8 subcategorías)
# ------------------------------------------------------------
#   └─ Carne De Cerdo (4 productos)
#   └─ Carne Roja (2 productos)
#   └─ Carne Roja Importada (1 productos)
#   └─ Chorizos Y Longanizas Empacados (12 productos)
#   └─ Jamones (16 productos)
#   └─ Pate, Tocino Y Otros Embutidos (13 productos)
#   └─ Pollo (3 productos)
#   └─ Salchichas (10 productos)
#
# 📁 Cuidado Del Hogar / Hogar Y Librería (5 subcategorías)
# ------------------------------------------------------------
#   └─ Articulos De Parafina Y Fosforos (1 productos)
#   └─ Camping (4 productos)
#   └─ Cocina (6 productos)
#   └─ Hogar (113 productos)
#   └─ Libreria (7 productos)
#
# 📁 Cuidado Del Hogar / Limpieza, Ropa Y Hogar (13 subcategorías)
# ------------------------------------------------------------
#   └─ Ambientales E Insecticidas (10 productos)
#   └─ Baterias E Iluminación (8 productos)
#   └─ Cepillos Y Accesorios Para Barrer Y Trapear (1 productos)
#   └─ Cloro (1 productos)
#   └─ Desinfectantes Y Ceras (22 productos)
#   └─ Detergentes En Polvo Y Liquidos (48 productos)
#   └─ Lavaplatos (13 productos)
#   └─ Limpiadores Para El Hogar Y Baño (13 productos)
#   └─ Papel Higienico (9 productos)
#   └─ Servilletas De Papel (4 productos)
#   └─ Suavizantes De Ropa (14 productos)
#   └─ Toallas De Papel (7 productos)
#   └─ Vajillas Y Cubiertos Desechables (27 productos)
#
# 📁 Cuidado Personal (12 subcategorías)
# ------------------------------------------------------------
#   └─ Articulos Para Afeitar (20 productos)
#   └─ Cremas Corporales Y Bloqueadores (12 productos)
#   └─ Cremas Y Cuidado Facial (18 productos)
#   └─ Desodorantes (47 productos)
#   └─ Fijadores Y Accesorios Para El Cabello (15 productos)
#   └─ Higiene Bucal (28 productos)
#   └─ Incontinencia / Pañales Para Adulto (11 productos)
#   └─ Jabones Y Complementos De Baño (20 productos)
#   └─ Maquillaje (23 productos)
#   └─ Proteccion Femenina (23 productos)
#   └─ Shampoos, Acondicionadores Y Tratamientos (65 productos)
#   └─ Tintes Y Complementos (22 productos)
#
# 📁 Frutas/Verduras (3 subcategorías)
# ------------------------------------------------------------
#   └─ Complemento Frutas Y Verduras (9 productos)
#   └─ Frutas (1 productos)
#   └─ Verduras (1 productos)
#
# 📁 Lacteos Y Congelados (7 subcategorías)
# ------------------------------------------------------------
#   └─ Comida Congelada (27 productos)
#   └─ Helados, Postres Y Hielo (14 productos)
#   └─ Huevos (4 productos)
#   └─ Leche Liquidas, Fluidas Y Saborizadas (12 productos)
#   └─ Mariscos Congelados (1 productos)
#   └─ Queso, Crema Y Mantequilla (69 productos)
#   └─ Yogurt (76 productos)
#
# 📁 Mascotas (4 subcategorías)
# ------------------------------------------------------------
#   └─ Accesorios De Mascotas (6 productos)
#   └─ Alimentos P/Gatos (11 productos)
#   └─ Alimentos P/Perros (29 productos)
#   └─ Articulos P/Cuidado D/Mascotas (3 productos)
#
# 📁 Medicinales (4 subcategorías)
# ------------------------------------------------------------
#   └─ Analgésicos (3 productos)
#   └─ Antigripales (7 productos)
#   └─ Gastro Intestinales (10 productos)
#   └─ Primeros Auxilios (1 productos)
#
# 📁 Panaderia (6 subcategorías)
# ------------------------------------------------------------
#   └─ Artesanal (3 productos)
#   └─ Especializados (4 productos)
#   └─ Pan Hamburguesa Y Hot Dog (1 productos)
#   └─ Pan Sandwich (2 productos)
#   └─ Reposteria (5 productos)
#   └─ Tortillas De Harina (1 productos)
#
# 📁 Snacks Y Dulces (5 subcategorías)
# ------------------------------------------------------------
#   └─ Boquitas (78 productos)
#   └─ Chocolates (32 productos)
#   └─ Dulces (28 productos)
#   └─ Galletas Dulces (29 productos)
#   └─ Galletas Saladas (8 productos)
#
# ============================================================
# Total categorías: 13
# Total subcategorías: 109
# Total productos: 1922

# %%
# Imprimir todas las categorías y subcategorías (solo comestibles)
print("=" * 60)
print("CATEGORÍAS Y SUBCATEGORÍAS (SOLO COMESTIBLES)")
print("=" * 60)

# Categorías no comestibles a excluir
categorias_no_comestibles = [
    "Bebe",
    "Cuidado Del Hogar / Hogar Y Librería",
    "Cuidado Del Hogar / Limpieza, Ropa Y Hogar",
    "Cuidado Personal",
    "Mascotas",
    "Medicinales"
]

# Filtrar DataFrame para excluir categorías no comestibles
if 'categoria' in df_spanish.columns and 'subcategoria' in df_spanish.columns:
    # Filtrar productos comestibles
    df_comestibles = df_spanish[~df_spanish['categoria'].isin(categorias_no_comestibles)]
    
    # Agrupar por categoría y obtener subcategorías únicas
    categorias_subcategorias = df_comestibles.groupby('categoria')['subcategoria'].unique()
    
    # Ordenar alfabéticamente por categoría
    for categoria in sorted(categorias_subcategorias.index):
        subcategorias = categorias_subcategorias[categoria]
        print(f"\n📁 {categoria} ({len(subcategorias)} subcategorías)")
        print("-" * 60)
        
        # Ordenar subcategorías alfabéticamente
        for subcat in sorted(subcategorias):
            # Contar productos en esta subcategoría
            count = len(df_comestibles[(df_comestibles['categoria'] == categoria) & 
                                      (df_comestibles['subcategoria'] == subcat)])
            print(f"  └─ {subcat} ({count} productos)")
    
    print("\n" + "=" * 60)
    print(f"Total categorías comestibles: {df_comestibles['categoria'].nunique()}")
    print(f"Total subcategorías comestibles: {df_comestibles['subcategoria'].nunique()}")
    print(f"Total productos comestibles: {len(df_comestibles)}")
    print(f"\nProductos excluidos (no comestibles): {len(df_spanish) - len(df_comestibles)}")
else:
    print("Error: No se encontraron las columnas 'categoria' o 'subcategoria'")
# Out:
# ============================================================
# CATEGORÍAS Y SUBCATEGORÍAS (SOLO COMESTIBLES)
# ============================================================
#
# 📁 Abarrotes (29 subcategorías)
# ------------------------------------------------------------
#   └─ Aceite Comestible (18 productos)
#   └─ Aderezos Y Mayonesas (21 productos)
#   └─ Atun Y Sardinas Envasadas (20 productos)
#   └─ Barras De Cereales (2 productos)
#   └─ Café, Te Y Cremoras (55 productos)
#   └─ Cereales (41 productos)
#   └─ Cereales Calientes / Atoles (14 productos)
#   └─ Complementos De Reposteria (13 productos)
#   └─ Especias Y Sazonadores (44 productos)
#   └─ Frijol Envasado (12 productos)
#   └─ Fruta Seca Y Deshidratada (1 productos)
#   └─ Frutas Envasadas Y En Almibar (3 productos)
#   └─ Gelatinas, Flanes Y Pudines (14 productos)
#   └─ Granos Basicos (5 productos)
#   └─ Harinas De Trigo (12 productos)
#   └─ Leche En Polvo (8 productos)
#   └─ Leche Liquida Uht (43 productos)
#   └─ Margarinas Y Mantecas (8 productos)
#   └─ Miel, Jaleas Y Mermeladas (15 productos)
#   └─ Modificadores De Leche (1 productos)
#   └─ Pastas Alimenticias (22 productos)
#   └─ Preparados De Cocina (3 productos)
#   └─ Sal (2 productos)
#   └─ Salsas (23 productos)
#   └─ Sopas Deshidratadas (10 productos)
#   └─ Sopas Tipo Ramen (13 productos)
#   └─ Tomate Procesado (12 productos)
#   └─ Vegetales Envasados (15 productos)
#   └─ Vinagres (3 productos)
#
# 📁 Bebidas (9 subcategorías)
# ------------------------------------------------------------
#   └─ Bebidas De Aloe (3 productos)
#   └─ Bebidas Energizantes E Isotonicas (22 productos)
#   └─ Cervezas (24 productos)
#   └─ Gaseosas (61 productos)
#   └─ Jugos Refrigerados (13 productos)
#   └─ Jugos Y Nectares (25 productos)
#   └─ Refrescos En Polvo Y Concentrados (17 productos)
#   └─ Te Frio Y Refrescos Saludables (17 productos)
#   └─ Vinos (91 productos)
#
# 📁 Carnes Y Embutidos (8 subcategorías)
# ------------------------------------------------------------
#   └─ Carne De Cerdo (4 productos)
#   └─ Carne Roja (2 productos)
#   └─ Carne Roja Importada (1 productos)
#   └─ Chorizos Y Longanizas Empacados (12 productos)
#   └─ Jamones (16 productos)
#   └─ Pate, Tocino Y Otros Embutidos (13 productos)
#   └─ Pollo (3 productos)
#   └─ Salchichas (10 productos)
#
# 📁 Frutas/Verduras (3 subcategorías)
# ------------------------------------------------------------
#   └─ Complemento Frutas Y Verduras (9 productos)
#   └─ Frutas (1 productos)
#   └─ Verduras (1 productos)
#
# 📁 Lacteos Y Congelados (7 subcategorías)
# ------------------------------------------------------------
#   └─ Comida Congelada (27 productos)
#   └─ Helados, Postres Y Hielo (14 productos)
#   └─ Huevos (4 productos)
#   └─ Leche Liquidas, Fluidas Y Saborizadas (12 productos)
#   └─ Mariscos Congelados (1 productos)
#   └─ Queso, Crema Y Mantequilla (69 productos)
#   └─ Yogurt (76 productos)
#
# 📁 Panaderia (6 subcategorías)
# ------------------------------------------------------------
#   └─ Artesanal (3 productos)
#   └─ Especializados (4 productos)
#   └─ Pan Hamburguesa Y Hot Dog (1 productos)
#   └─ Pan Sandwich (2 productos)
#   └─ Reposteria (5 productos)
#   └─ Tortillas De Harina (1 productos)
#
# 📁 Snacks Y Dulces (5 subcategorías)
# ------------------------------------------------------------
#   └─ Boquitas (78 productos)
#   └─ Chocolates (32 productos)
#   └─ Dulces (28 productos)
#   └─ Galletas Dulces (29 productos)
#   └─ Galletas Saladas (8 productos)
#
# ============================================================
# Total categorías comestibles: 7
# Total subcategorías comestibles: 67
# Total productos comestibles: 1192
#
# Productos excluidos (no comestibles): 730

# %%
# Imprimir todos los productos con su precio (solo comestibles) y guardar en TXT
from io import StringIO

# Crear un buffer de texto para capturar todo el output
output_buffer = StringIO()

def print_and_save(text):
    """Imprime y guarda el texto en el buffer"""
    print(text)
    output_buffer.write(text + "\n")

print_and_save("=" * 60)
print_and_save("PRODUCTOS COMESTIBLES CON PRECIOS")
print_and_save("=" * 60)

# Categorías no comestibles a excluir
categorias_no_comestibles = [
    "Bebe",
    "Cuidado Del Hogar / Hogar Y Librería",
    "Cuidado Del Hogar / Limpieza, Ropa Y Hogar",
    "Cuidado Personal",
    "Mascotas",
    "Medicinales"
]

# Filtrar DataFrame para excluir categorías no comestibles
if 'categoria' in df_spanish.columns and 'subcategoria' in df_spanish.columns:
    # Filtrar productos comestibles
    df_comestibles = df_spanish[~df_spanish['categoria'].isin(categorias_no_comestibles)].copy()
    
    # Ordenar por categoría, subcategoría y nombre
    df_comestibles = df_comestibles.sort_values(['categoria', 'subcategoria', 'nombre'])
    
    # Obtener categorías únicas ordenadas
    categorias = sorted(df_comestibles['categoria'].unique())
    
    for categoria in categorias:
        df_categoria = df_comestibles[df_comestibles['categoria'] == categoria]
        subcategorias = sorted(df_categoria['subcategoria'].unique())
        
        print_and_save(f"\nCATEGORIA: {categoria}")
        print_and_save("=" * 60)
        
        for subcategoria in subcategorias:
            df_subcat = df_categoria[df_categoria['subcategoria'] == subcategoria]
            
            print_and_save(f"\n  SUBCATEGORIA: {subcategoria} ({len(df_subcat)} productos)")
            print_and_save("  " + "-" * 58)
            
            # Imprimir cada producto con su precio
            for idx, row in df_subcat.iterrows():
                nombre = row.get('nombre', 'N/A')
                precio = row.get('precio', 'N/A')
                
                # Formatear precio (convertir a string si es numérico)
                if pd.notna(precio):
                    try:
                        precio_num = float(precio)
                        precio_str = f"Q{precio_num:.2f}"
                    except:
                        precio_str = f"Q{precio}"
                else:
                    precio_str = "Q0.00"
                
                print_and_save(f"    {nombre} - {precio_str}")
    
    print_and_save("\n" + "=" * 60)
    print_and_save(f"Total productos comestibles mostrados: {len(df_comestibles)}")
    
    # Guardar en archivo TXT
    output_filename = latest_json.stem.replace(".json", "") + "_productos_comestibles.txt"
    output_path = data_dir / output_filename
    
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(output_buffer.getvalue())
    
    print(f"\nArchivo guardado: {output_path.absolute()}")
else:
    print("Error: No se encontraron las columnas 'categoria' o 'subcategoria'")
#     Yogurt Lala Bebible Fresa Mora 200g - Q7.15
#     Yogurt Lala Bebible Manzana 200g - Q7.15
#     Yogurt Lala Griego Natural Sin Azucar Bote 900g - Q52.45
#     Yogurt Oikos Griego Natural Sin Azucar Bote 900g - Q59.05
#     Yogurt Oikos Natural 900g - Q57.20
#     Yogurt Yes Bebible Aloe Vera 212g/200ml - Q5.60
#     Yogurt Yes Bebible Banano Fresa 212g/200ml - Q5.60
#     Yogurt Yes Bebible Banano Fresa S/Azucar 206g - Q5.60
#     Yogurt Yes Bebible Fresa 212g/200ml - Q5.60
#     Yogurt Yes Bebible Fresa Probioticos S/Azucar 206g - Q5.60
#     Yogurt Yes Bebible Manzana 212g/200ml - Q6.25
#     Yogurt Yes Bebible Melocoton 212g/200ml - Q5.60
#     Yogurt Yes Bebible Pina Colada 212g/200ml - Q5.60
#     Yogurt Yolu Cremoso Sabor Fresa 125ml - Q3.55
#     Yogurt Yolu Cremoso Sabor Fresa 900ml - Q24.95
#     Yogurt Yolu Cremoso Sabor Melocoton 125ml - Q3.55
#     Yogurt Yolu Cremoso Sabor Melocoton 900ml - Q24.95
#     Yogurt Yolu Cremoso Sabor Natural 125ml - Q3.55
#     Yogurt Yolu Cremoso Sabor Natural 900ml - Q24.95
#     Yogurt Yoplait Infantil C/Topping Choco Fresa 127g - Q9.15
#     Yogurth Lala Batido Natural 125g - Q4.35
#
# CATEGORIA: Panaderia
# ============================================================
#
#   SUBCATEGORIA: Artesanal (3 productos)
#   ----------------------------------------------------------
#     Magdalena Blini De Vainilla Und - Q25.75
#     Pan P/Shukos Blini Bolsa 6u - Q8.25
#     Pan Tostado Blini Variedad Bolsa 10u - Q12.25
#
#   SUBCATEGORIA: Especializados (4 productos)
#   ----------------------------------------------------------
#     Base Pizza Mission Crust Bolsa 350g - Q12.75
#     Tostada Fleiv De Maiz Bolsa 400g - Q13.75
#     Tostadas Boca2 Med. 485g. - Q21.95
#     Tostadas Milpa Real Ondula 30u 360g - Q21.45
#
#   SUBCATEGORIA: Pan Hamburguesa Y Hot Dog (1 productos)
#   ----------------------------------------------------------
#     Pan Hamburguesa Blini Paq 5u. - Q10.75
#
#   SUBCATEGORIA: Pan Sandwich (2 productos)
#   ----------------------------------------------------------
#     Pan Sandwich Blini Integral 550g - Q17.25
#     Pan Sandwich Europa Semillas Cereales 570g - Q26.45
#
#   SUBCATEGORIA: Reposteria (5 productos)
#   ----------------------------------------------------------
#     Panettone Arcor Frutas Cristalizadas Caja 400g - Q49.95
#     Pastelito Gansito Marinela Chocolate 50g - Q6.45
#     Pastelito Marinela Dalmata Cobertura Blanca 45g - Q6.45
#     Pastelito Pinguino Marinela Minix Bolsa 204g - Q26.25
#     Pinguino Marinela Navidenos 80g - Q10.55
#
#   SUBCATEGORIA: Tortillas De Harina (1 productos)
#   ----------------------------------------------------------
#     Tortilla D/Harina Tortiamigos Grd Bolsa 10u 650g - Q17.35
#
# CATEGORIA: Snacks Y Dulces
# ============================================================
#
#   SUBCATEGORIA: Boquitas (78 productos)
